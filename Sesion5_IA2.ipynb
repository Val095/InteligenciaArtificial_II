# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion5_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sesión 5**
#
# Extracción, carga y Transformación
#
# Funcionalidades empresariales
#
# Dinero, Tiemmpo y Factor de calidad
#
# Seguridad, Viabilidad, Mantenibilidad, Escalabilidad, Sostenibilidad, Usabilidad (factores de calidad)
#
# KDD y CRISP-DM: minería de datos
#
# **VIDEO KDD**
#
# caos a conocimiento puro de alto valor
#
# saber como refinar los datos
#
# descubrimiento de conocimientos en bases de datos (KDD)
#
# ¿como el caos se vuelve una recomendación perfecta?
#
# miles de millones de registros que se generan a nivel mundial, esto ahoga a las organizaciones modernas
#
# deben tener un marco computacional estructurado
#
# 1. El valor de los datos
#
# información guardada en los servidores en crudo
#
# los datos crudos tienen un valor inmenso pero estan ocultos debajo de capas de ruido
#
# hay que hacer un refinamiento metículoso
#
# 2. Orígenes y conceptos
#
# 1989 - acuñar el termino kdd
#
# 1996 - formalizar el proceso KDD
#
# 2016 - publicacion de KDD y se expande y se adapta al Big Data moderno
#
# la minería de datos es un paso algorítmico especifico.
#
# el kdd es la fábrica completo
#
# 3. Tutorial
#
# Fayyad propone los pasos formales del proceso KDD en 1996
#
# - Seleccion: aislar solo lo que nos sirve
#
# - preproceso: limpiar el crudo.
#
# -transformacion: darle estructura matematica a los datos ya limpios.
#
# -minería: busqueda de patrones novedosos y relaciones.
#
# - evaluacion: visualizacion de resultados.
#
# 4. Aplicaciones reales
# Finanzas: Detección de fraude
#
# Salud:diagnóstico temprano
#
# Retail: analisis de canasta
#
# 5. Futuro del conocimiento
#
# La seguridad y privacidad son críticos.
#
# Los procesos de limpieza deben manejar los datos anónimos.
#
# _**"La invasion a la privacidad se concecta al reconocimiento de patrones"**_
#
# **VIDEO 2 CRISP-DM: El plano Maestro**
#
# 1996 - Concebido
#
# 1999 - Publicación oficial de CRISP-DM 1.0
#
# 2015 - Extensión ASUM-DM por IBM
#
# 1. Orígenes y practica
#
# CRISP-DM un ciclo de vida dinámico e iterativo de 6 fases.
#
#
# 2. Negocio y los datos
#
# Fase 1: traducir un problema a objetivos de datos.
#
# Objetivos
# Situacion
# Metas Datos
# Plan
#
# Fase2: Datos
#
# Recolectar, describir, explorar, calidad
#
# 3. Preparación
#
# Que tan limpios estan los datos
#
# tomar la informacion cruda y se transforma en un conjunto impecable aplicando tecnicas de normalizacion.
#
# 50 y 80% del proyecto
#
#
# 4. modelado y evaluación
#
# Técnica
#
# prueba
#
# construir
#
# Evaluacion: Resultados, proceso, proximos
#
# 5. Despliegue y futuro
#
# Integración operativa
#
# Despliegue
#
# Monitoreo
#
# Informe
#
# Revisión
#
# Los resultados hablan por si solos
#
# ¿Cómo evolucionará con la IA moderna?
