# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesi%C3%B3n3_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 3**
#
# En esta clase iniciamos dando un breve resumen de lo que vimos el día de ayer en la sesión 2 y dando opiniones personales sobre la Inteligencia Artificial.
#
# En sí la clase iniciamos viendo la historia del universo por medio del Big Bang el cual hizo posible la creación de galaxias, planetas y sistemas de los cuales salió el polaneta Tierra en donde habitamos, asimismo la evolución de los humanos y como estos desarrollaron el pensamiento crítico necesario para crear y utilizar herrramientas que faciliten las actividades, desde las lanzas hasta hoy en día los sistemas inteligentes.
#
# Como evolución de la Inteligencia Artificial vimos en unos cuadros como inicia con el manejo de negocios y este mismo empieza a desglosar sus funciones con el manejo de datos, luego con la ciencia de datos y la analítica de datos. De la misma manera la inteligencia de negocios, el Machine Learning y por último la inteligencia artificial. Esto nos deja como todo inicia desde la revisión de los cases de estudio de negocios, los reportes preliminares, la creación de dashboards, hasta el reconocimiento de voz y el razonamiento simbólico.
#
# En la siguiente parte se mencionó la analítica avanzada en donde el pasado y el futuro se pueden diferenciar. Además que la inteligencia artificial predictiva utiliza redes neuronales para poder dar las respuesta y se compara con las neuronas del cerebro humano, en donde al momento de dormir, las neuronas crean predicciones de un futuro, que se refleja por medio de los sueños.
#
# Predecir: Lo que podría suceder.
#
# Preescribir: Lo que puedes suceder en el futuro.
#
# También mencionamos el manejo de la infraestructura  de los datos que incluye el **Esquema tradicional** y la **Big Data** en donde el esquema tradicional se enfoca en utilizar bases de datos tradicionales  y usan lenguajes como Python y SQL. En cambio la Big Data usa unas bases de datos para manejo de informasión masiva, en donde usa lenguajes como Python, Java y Escala.
#
# Por otro lado evimos la ciencia de datos en donde están 3 componentes que son:
#
# **Inteligencia de Negocios** en donde  se analizan los datos y se usan métricas,KPI's, reportes y dashboards.
#
# **Métodos tradicionales** donde se usa la regresión y el clustering
#
# **Machine Learning** en donde se maneja el aprendizaje supervisado y aprendizaje no supervisado de los sistemas inteligentes.
#
# Para finalizar se menciona una parte de Google Cloud, el cual es una herramienta que, según lo visto en la clase, se pueden cargar las máquinas virtuales que uno utilice para sus proyectos, se ven las **Big Query** que son las bodegas de datos masivos. Asimismo las bases de datos y lo más nuevo que se integró es la parte de Inteligencia Artificial.
