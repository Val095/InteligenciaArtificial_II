# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesi%C3%B3n1_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESIÓN 1**
# comenzamos viendo la parte de modelación de patrones complejos no lineales.
#
# 1. Hacia la IA Avanzada
# Esta primera parte nos habla del ecosistema técnológico a tener para mejor eficiencia al desarrollar. Este consiste en utilizar herramientas eficaces como:
# -Python
# -Google Colab
# -Git y Github
#
# 2. Preparación de datos
# Esta segunda parte nos menciona sobre la **fuga de datos** que es la filtración de información del conjunto de prueba.
#
# Nos muestra un proceso el cual es
# Imputación - Escalamiento - Reducción - Clasificador
# esto se hace baje una cápsula que contiene el código
#
# 3. Modelos supervisados
# Empieza hablando del **Truco de Kernel** que es el que proyecta datos a dimensiones superiores.
# También nos habla de **Bagging** que reduce la varianza y el **Boosting** que reduce el sesgo.
#
# 4. IA no supervisada
# Habla sobre los algoritmos **Kmeans** que es bueno para agrupación, el **DBscan** que es bueno para la densidad y el **Isolation Forest** que es para la detección de anomalías.
# Asimismo del análisis de componentes en el cual se comprimen los datos, se seleccionan los más relevantes y los que no son necesarios se excluyen del resto.
#
# 5. Evaluación de modelos
# Nos comienza hablando del **sesgo y varianza** que es el equilibrio matemático entre modelos que hacen suposiciones simples y modelos más sensibles a ruidos y variaciones.
# Nos muestra el **GridSearchCV** que hace búsquedas exhaustivas y costosas y el **RandomizedSearch** que hace búsquedas más rápidas y menos costosas.
#
# Por último tenemos las métricas avanzadas las cuales contienen:
# - Matrices de confusion
# -Precisión y exhaustividad
# - F1-scale
# ROC.
#
# **PREGUNTA FINAL**
#
# ¿Cómo transformará la IA predictiva a la Industria 5.0?
