# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion12_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 12**
#
# **VIDEO ARBOLES DE DECISION**
#
# ver como toma sus decisiones algoritmicas.
#
# Modelos de caja blanca: algoritmo con reglas de clasificación transparentes y fáciles de interpretar paso a paso.
#
# Se puede revisar el modelo de inicio a fin y ver la lógica de cada predicción.
#
# 1. Entrenando árboles
#
# árbol de decision entrenando datos con iris.
#
# Requiere casi nula preparacion de los datos, toma los datos crudos y traza las divisiones.
#
# Nodo raíz, luego pasa a los nodos de division (si o no), finalmente a los nodos hojas que toman la decision
#
# 2. Predicciones y probabilidades
#
# Inicio
#
# Evaluacion
#
# Descenso - descender por la rama
#
# Resultado - alcanzar la hoja y calcular.
#
# Fronteras de decisión ortogonales en características. Las divisiones segmentan el espacio para clasificar la realidad de la informacion
#
# 3. CART e impureza
#
# Arbol de clasificacion y regresion, clasificar los datos buscando impurezas
#
# busca la mejor division sin pararse a poensar si será la más optima más adelante.
#
# Gini - rapida de procesar y aislar la clase mas frecuente
#
# entropia - nivel de caos en nuestros datos
#
# 4. Regularización
#
# modelos no paramétricos, libertad para adaptarse a los datos.
#
# Aplicar regularización para que el arbol no crezca tanto, poniendo límites
#
# las decisiones se vuelven erráticas buscando atrapar datos innecesarios.
#
# si se regulariza el modelo da mejor rendimiento
#
# 5. Arboles de regresión
#
# El nodo hoja se vuelve un valor continuo.
#
# la falta de control es peligrosa, ya que trata de imitar cada salto y ruido de los datos, al regularizarlo el modelo se vuelve robusto
#
# 6. limitaciones
#
# es muy rígido ya que hace divisiones en ángulos rectos, es sensible a la rotación y orientación.
#
# El talon de aquiles es la varianza, ya que si se cambia una parte de los datos de entrenamiento, el arbol puede cambiar todo el diseño
#
# ¿como superar esta alta varianza en los modelos?
#
# entrenar a los modelos y promediar sus resultados para cancerlar los errores.
#
# -------------------------------------------------------------------
#
# un arbol de decisión, un árbol de regresion y un ejemplo de random forest que nos ilustre como se manejan los hiperparametros de una manera pedagógica y didáctica en google ai studio
#
# https://ai.studio/apps/1586590f-5561-4012-8bdc-986688fa628d
