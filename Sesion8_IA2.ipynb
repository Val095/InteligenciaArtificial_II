# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion8_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sesión 8**
#
# Antigravity - es una plataforma y entorno de desarrollo (IDE) gratuito creado por Google que utiliza agentes de inteligencia artificial autónomos para planificar, programar y probar aplicaciones completas a partir de instrucciones simples.
#
#   APP para gestión de proyectos por medio de Zcode
#
#   Ver los agentes y par qe sirve cada uno, dependiendo del enfoque y la tarea hay que tener en cuenyta como funciona cada agente, Inteligencia, Velocidad y Costo por tarea.
#
#   NotebookLM
#
#   ----------------------------------------------------------------
#
#   **VIDEO ML EXTREMO A EXTREMO**
#
#   ¿De datos crudos a decisiones rentables?
#
#   El machine Learning se basa en construir un motor para devolvernos decisiones rentables
#
#   1. Visión y obtención
#
#   Pipeline para inversiones mobiliarias
#
#   La salida de nuestro modelo alimenta a un análisis
#
#   Pipeline: Secuencua de componentes de procesamiento de datos asícronos. Si un componente falla no se cae todo.
#
#   Definir meta
#
#   Medir éxito
#
#   Baja datos
#
#   2. Exploración y visualización
#
#   Ocultare l conjunto de prueba para evitar sesgos humanos.
#
#   Los datos necesitan un orden
#
#   3. Preparación de los datos
#
#   Los datos crudos desordenados arruinan los algoritmos. Implementar estrategias para convertir el texto en números
#
#   No solo de limpia, también se innova (Ingeniería de características)
#
#   4. Selección y entrenamiento
#
#   Se eleige el cerebro algorítmico
#
#   Regresión lineal
#
#   Árboles de decisión
#
#   Bosques aleatorios
#
#   Sobreajuste: Memoriza el entrennamiento pero falla al generar casos nuevos.
#
#   Regresión lineal: rendimiento pobre y validación pobre
#
#   Árboles de decisión: mantiene un rendimiento perfecto
#
#   5. Ajuste y presentación
#
#   Búsqueda de cuadrícula Evalúa hiperparámetros con validación cruzada para hallar la mejor opción.
#
#   Evaluar los resultados con el mundo real.
#
#   6. Lanzamiento y monitoreo
#
#   No se termina el proyecto al implementar el código, Se requiere infraestructura para mantenerse a largo plazo. Reentrenar al modelo contrantemente sino ocurre la pudrición del modelo.
#
#   Si los datos evolucionan, se debe actualizar y reentrenar el modelo
#
#   _**¿Qué joyas ocultas descubrirá hoy una empresa si decide construir su poropio pipeline de datos?**_
