# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion17_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 17**
#
# **VIDEO ENTRENANDO REDES PROFUNDAS**
#
# 1. Reto de los gradientes
#
# Gradiente inestable: Problema donde las señales de errore se desvanecen o explotan al propagarse por redes profundas.
#
# en explosion el mensaje puede destruir las conexiones ya establecidas
#
# 2. Inicialización
#
# Método glorot la varianza de las entradas debe ser igual a la de las salidas, se logra mediante funciones de activación específicas, funciones sigmoides
#
# He, calibra los pesos desde el primer instante
#
# 3. Funciones de activación
#
# las neuronas se traban solo emitiendo ceros, se le agrega una pendiente para que las neuronas nunca mueran.
#
# Funciones suaves ELU y SELU para lograr la auto-normalización apilando varias capas.
#
# Curvas GELU, Swish y Mish, variantes no monotonas para flujos de datos negativos sin perder estabilidad
#
# 4. Normalización
#
# Metricas -Evalúa la media y desviacion en el mini-lote
#
# Centrar - Normalizar entradas
#
# Escalar - Multiplica señal
#
# Desplazar - ajusta usando el parámetro aprendido
#
# recorte de gradientes: cortar un gradiente que quiere causar errores
#
# 5. Aprendizaje por transferencia
#
# Reutilizar capas de redes profundas ya entrenadas para tareas nuevas, ahorrando grandes recursos.
#
# Congela capas base y ajusta únicamente las capas superiores de una red ya entrenada. A medida que el modelo se estabiliza se pueden ir descongelando las capas inferiores.
#
# Esta técnica condujo al renacimiento de las redes neuronales
#
# 6. Preentrenamiento
#
# La red aprende detectores de caracteristicas de alto nivel mediante el preentrenamiento no supervisado.
#
# Pequeña fracción de datos etiquetados.
#
# la regularizacion que apaga naueronas duranre el entrenamiento, evitamos que la red se vuelva dependiente en momentos complejos.
#
# ¿Como evolucionara esta arquitectura en las redes futuras?
