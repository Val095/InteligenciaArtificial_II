# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion10_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 10**
#
# **VIDEO Entrenando Modelos**
#
# 1. Regresión lineal
#
# ECUACION NORMAL: Solución matematica directa que calcula los parámetros optimos para minimizar el error.
#
# 2. Método del gradiente
#
# Derivadas: Calcular las derivadas parciales de la función
#
# Descenso: Dar un paso en la direccion donde el costo disminuye
#
# Tolerancia: Repetir hasta que el vector del gradiente sea mínimo
#
# Lotes, estocástico, mini-lotes.
#
# todo el set, un solo dato, set pequeño
#
# El método estocástico rebota, ayudando a escapar de mínimos locales.
#
# Rutas de los tres algoritmos en el espacio de parámetros.
#
# 3. Regresión Polinomial
#
# Modelo lineal adaptado a datos complejos usando características elevadas.
#
# 4. Curvas de aprendizaje
#
# Mesetas altas y muy juntas diagnostican claramente un subajuste.
#
# Una gran brecha entre las crurvas evidencia un grave sobreajuste. (el modelo memorizó los datos de entrenamiento)
#
# 5. Regularización
#
# Aplicar restricciones matemáticas
#
# Regresion reach
#
# Regresion lazo
#
# Astignet
#
# La parada temprana frena el entrenamiento en el punto mínimo de error.
#
# Rescatar el modelo antes de que se corrompa
#
# Reduciendo costos del hardware
#
# 6. Modelos de clasificacion
#
# ¿Cómo adaptar la optimización a clases discretas?
#
# regresion logistica y softmark
#
# ------------------------------------------------------------------------
#
#
# Sistema de prediccion de las casas adaptarlo para la sociedad colombiana (dataset con datos de bogotá) hacer comparación de la regresión lineal y la regresión logística en ese modelo.
