# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion18_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 18**
#
# Python, Keras, Tensorflow y Pytorch
#
# -------------------------------------------------------
#
# _**VIDEO TENSORFLOW A MEDIDA**_
#
# 1. Bloques fundamentales
#
# Arreglos de numpy, al dar el salto al aprendizaje profundo hay que cambiar a Tensorflow, ya que este usa 32 bits, reduciendo el uso de memoria a la mitad
#
# un sistema inteligente por definicion necesita alterar sus conexiones, ahí entra tfvariable
#
# 2. Personalizacion avanzada
#
# Nuestros datos están llenos de ruido, funcions de perdida personalizada, ayuda a que el sistema no entre en error por cualquier dato anómalo
#
# 3. Calculo de grradientes
#
# Autodiferenciacion de modo inverso: tecnica eficiente en dos pasadas para calular gradientes en redes con multiples parámetros
#
# TF.Gradient, funciona  como la caja negra de un avion, grabando cada operacion matemática y se le pide que la entregue en reversa
#
# 4. Buclosa de entrenamiento
#
# Muestrear - obtener un lote aleatorio de datos
#
# Paso adelante - Calcular la pérdida dentro de un GradientTape
#
# Gradientes - Calcular derivadas usando la cinta
#
# Optimizar - Aplicar gradientes con un optimizador
#
# El control manual da mayor flexibilidad, nos permite asignar optimizadores a cada rama
#
# 5. Funciones y grafos
#
# Grafo de computación: Red matemática abstracta que elimina nodos inutiles y permita la ejecucion de paralelos masivos
#
# No se pueden usar bibliotecas externas
#
# el 95% de casos no requeriran keras
#
# ¿Qué arquitecturas futuristas diseñaremos a continuación?
#
# ------------------------------------------------------------------
#
# _**VIDEO VISON POR COMPUTADORA**_
#
# 1. Inspiración biológica
#
# La naturaleza por los años 50 se hicieron experimentos con los gatos, viendo que las neironas no procesan todo de una vez, sino por partes
#
# Campo receptivo local: Region del campo visual donde una neurona reacciona a estímulos
#
# 2. Capas y filtros
#
# Definir filtro - Crear un Kernel para extraer características
#
# Aplicar Zancada - Deslizar el filtro por la imagen (Stride)
#
# Añadir relleno - Usar relleno de ceros para bordes (Padding)
#
# El tamaño de los pasos que da el scaner es lo que se llama Zancada, si se cambia a saltos mas grandes ayuda a analizar la imagen más rápido
#
# si usamos multiples filtros podemos crear mapas de caraterísticas en 3d
#
# 3. Agrupacion (pooling)
#
# se necesita aun forma de comprimir la informacion sin perder lo importante
#
# Obliga a la red a concentrarse en las carcateristicas mas significantes
#
# Max pooling reduce la imagen conervando detalles clave.
#
# 4. Arquitecturas de red famosas
#
# 1998 - LeNet-5 para lectura de cheques bancarios
#
# 2012 - AlexNet aplia capas convolucionales
#
# 2014 - GoogLeNet introduce módulos Inception.
#
# 2015 - ResNet usa conexiones de salto (skip)
#
# La innovación no se detuvo, hoy en dia se cuentan con modelos más optimizados, ligeros y escalablesssssssssssss
#
# 5. Modelos preentrenados
#
# Se usa el aprendizaje por transferencia, se toma un modelo que sabe como se ve el mundo en general y se le modifican las últimas capas
#
# 6. Detección y segmentación de objetos
#
# Pasamos de la clasificacion a dibiujar cuadros delimitadores al rededor del objetos
#
# Red convolucional procesando imágenes de distintos tamaños
#
# ¿Qué problema imposible resolverá mañana?
# --------------------------------------------------------------------
