# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion15_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 15**
#
# **VIDEO ORDEN DEL CAOS**
#
# informacion caotica sin informacion de como organizarla
#
# los datosson como océanos sin explorar
#
# 1. Datos no supervisados
#
# Agrupamiento: identificar y asignar datos similare a grupos basados en sus características.
#
# es el motor detrás de la toma de decisiones, ayuda con la segmentación de clientes en un proyecto. Transofmra datos crudos en acciones concretas
#
# 2. Agrupamiento y K-means
#
# Identifica cinco grupos distintos diferentes, ajusta el centroide de cada grupo. la IA usa metricas criticas
#
# Inercia
#
# Puntuacion de siluetas
#
# 3. Segmentación
#
# Segmentación de imagenes por color, aplicando kmeans agrupa los colores en grupos dismunuyendo la complejidad visual
#
# Entrenar - detectar instancias mas dudosas
#
# Etiquetar - un experto humano revisa y etiqueta los datos
#
# Iterar - repetir el proceso hasta optimizar el rendimiento
#
# 4. DBSCAN
#
# Algoritmo basado en densidad para identificar grupos continuos de formas paralelas.
#
# 5. Anomalías y novedades
#
# la deteccion de anomalias busca aislar eventos disruptivos.
#
# la deteccion de novedades busca detectar instancias raras.
#
# 6. Mezclas Gaussianas
#
# Crea zonas de desidad elípticas que se adaptan a la distribucion de los puntos.
#
# Criterios BIC  Y AIC - Métricas para calcular el numero optimo de grupos en modelos probabilísticos.
#
# ¿Cómo desbloquearan valor con estos datos?
#
# ---------------------------------------------------------------------
#
# algoritmos no supervisados y hacer una comparacion del kmeans con el dbscan para entender
