# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Clase4_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sesión 4**
#
# **Arneses**: es un entorno o un conjunto de herramientas diseñadas para probar, depurar o ejecutar componentes de software de manera aislada o controlada. Su propósito principal es simular el entorno operativo real de un componente, permitiendo a los desarrolladores probarlo sin necesidad de tener el sistema completo en funcionamiento.
#
# **Skills**: se refieren a las capacidades específicas que un agente puede realizar o las funcionalidades que posee para lograr sus objetivos.
#
# **Sistemas oprativos agénticos**: En este modelo, el sistema operativo actúa como el entorno de ejecución, la capa de seguridad y la infraestructura central donde múltiples agentes de IA viven, colaboran, toman decisiones y ejecutan acciones en el mundo digital.
#
#
# **Plano de machine learning - Video**
#
# _**1. Valor del ML**_
#
# **Machine Learning**
# Un programa mejora su rendimiento en una tarea específica tras adquirir mayor experiencia
#
# el ML facilita el aprendizaje mediante **minería de datos**
#
# _**2. Tipos de sistema de aprendizaje y niveles de supervision**_
#
# El sistema necesita un maestro que le entregue los paquetes etiquetados
# En no supervisado tiene que descubrir todo
#
# Aprendizaje por refuerzo: Aprende una estrategia óptima mediante recompensas.
#
# _**3. Flujos de datos y tipos de aprendizaje**_
#
# Aprendizaje por lotes
#
# Aprendizaje en línea permite una adaptación continua a datos nuevos.
#
# Aprendizaje fuera del núcleo
#
# _**4. Estrategias generales**_
#
# Aprendizaje basado en instancias
#
# Aprendizaje basado en modelos
#
# _**5. Desafíos principales y riesgos del sistema**_
#
# Ingeniería de Características
#
# El sobreajuste ocurre si un modelo complejo memoriza el ruido.
#
# Infrajuste es cuando el modelo es demasiado bajo
#
# _**6. Pruebas y validación**_
#
# Entrenamiento
#
# Validación
#
# Prueba final
#
# ¿Que riesgos tienen los modelos no supervisados?
#
# ------------------------------------------------------------------------
#
# Los LLMs masivos de alimentan de información de Web Scraper, Repositorios de Código, Literatura y libros y Artículos académicos y científicos.
