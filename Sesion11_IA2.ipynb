# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion11_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 11**
#
# **VIDEO VECTORES DE SOPORTE (SVM)**
#
# SVM: modelo versatil capaz de realizar clasificación lineal o no lineal, regresión y detección
#
# Procesa conjuntos de datos pequeños o medianos
#
# 1. Clasificacion lineal
#
# Clasificación de margen amplio con vectores en el límite
#
# En el mundo real los datos son caóticos,
#
# el margen duro es muy estricto, se ropme si aparece un dato atípico
#
# un margen blando es más permisivo
#
# Margen blando aujustando el hiperparámetro C: bajo y alto
#
# 2. Modelos no lineales
#
# Separando datos no lineales usando características polinomiales
#
# Transformar un espacio caótico de una dimension en uno de dos dimensiones en donde se pueda trazar una gráfica
#
# Identificar:
#
# Transformar
#
# Entrenar
#
# 3. El truco de Kernel
#
# Técnica matemática casi milagrosa, para obtener el mismo resultado sin tener que añadirlos
#
# Clasificador SVM con Kernerl polinomial de tercer y décimo grado.
#
# 4. Similitud y RBF
#
# Caracteríscitcas de similitud usando la función RBF Gaussiana.
#
# el protagonista es el hiperparametro llamado gamma.
#
# Cambios en gamma y C ajustan el rango de influencia de la frontera.
#
# 5. Regresión SVM
#
# Intenta encajar instancias dentro de  calle, medio por épsilon.
#
# Tolerancia a los errores, se controla por épsilon
#
# Regresión lo lineal ajustando la regularización con kernel
#
# 6. Matematica interna
#
# Minimizar los pesos resulta en un margen mucho más amplio
#
# todo radica en una restructuracion, se toma el problema de restructuración original y se traduce.
#
# ¿Qué patrones ocultos en los datos no estamos viendo?
#
# --------------------------------------------------------------------
#
# (google ais)simulador con el dataset del valor de las viviendas en dos o tres dimensiones, que podamos seleccionar las variables para ver las maquinas de soporte vectorial de forma educativa y pedagógica, con tal de hacer las comparaciones
#
# colab. Un código con el dataset del valor de las casas de máximo 30 líneas utilizando las máquinas de soporte vectorial, lineales y polinomiales, en donde cada línea tiene que estar comentada sin excepción
