# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion16_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 16**
#
# Hacer un perceptron en excel
#
# **VIDEO REDES NEURONALES CON KERAS**
#
# 1. Biología de redes
#
# Neurona biológica con cuerpo celular, dendritas y axón, de nuestro propio cerebro sale la inzpiracion.
#
# traduccion matemática, las dendritas se vuelven las entradas,
#
# 2. El perceptrón
#
# El corazón del perceptrón es la Unidad Lógica Umbral (TLU) aplicando una función escalón. Clasificador binario rápido
#
# en 1969 nos topamos con que un XOR no lo puede resolver un perceptrón
#
# 3. Retropropagacion y MLP
#
# Capas ocultas, de ahí nace el perceptrón multicapa, rompe la maldicion del XOR.
#
# Adelante - red procesa los datos y lanza prediccion
#
# Medir error - que tan equivocada estuvo
#
# Pase Inverso - regla de la cadena de calculo, saber que conexion tuvo la culpa
#
# Ajustar - descenso del gradiente
#
# ¿Cómo se contruyen estos modelos en la práctica?
#
# 4. Keras y API secuencial
#
# Muestras de fashion MNIST, un reemplazo moderno del MNIST - que la red pueda diferenciar entre prendas, es muy bueno para entrenar nuestra primera red neuronal
#
# Declarando el modelo, luego capa flatten, luego se agregan capas pcultas densas, y se remata conla capa de salida, para que el modelo diga en porcentaje su seguridad
#
# 5. La API funcional
#
# Wide & Deep - camino profundo lleno de capas con patrones dificiles, luego un camino ancho para llevar los datos a la salida.
#
# 6. API de subclases
#
# si el modelo requiere cambiar la forma durante la marcha, al heredar la clase model se tiene el control total, al estar oculto se vuelve opaco, requiere precisión.
#
# ¿Hasta donde llegar con Keras Tuner y TensorBoard?
#
# -------------------------------------------------------------------
#
# _**La mente artificial**_
#
# Introducción a las redes neuronales y Keras, de la biología a la arquitectura de sistemas.
#
# Naturaleza:
#
# Dendritas (Receptores) → Entradas(Inputs)
#
# Los datos brutos (x1, x2) ingresan al sistemas
#
# Máquina:
#
# Cuerpo Celular → Suma Ponderada: Se calcula la relevancia (peso) de cada entrada
#
# Axón → Función de Activación: Decide si la neurona se enciende y emite una señal
