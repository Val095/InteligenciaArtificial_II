# %% [markdown]
# <a href="https://colab.research.google.com/github/Val095/InteligenciaArtificial_II/blob/main/Sesion13_IA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 13**
#
# **VIDEO APRENDIZAJE POR CONJUNTOS**
#
# Tomar algoritmos simples y convertirlos en sistemas complejos
#
# 1. Introducción a conjuntos
#
# ¿Cómo varios aprendices débiles crean uno fuerte?
#
# Un sistema capaz de lograr predicciones muy estrictas.
#
# una moneda sesgada, 51% de caer en cara, si se lanza mil veces, la probabilidad sube al 75%
#
# 2. Clasificadores de votación
#
# Flujo esquematico de como se ensablan los predictores, por un lado la regresion logistica, vector de soportes o bosques aleatorios, por otro lado la prediccion
#
# votacion dura: cada voto cuenta por igual
#
# votacion liviana: probabilidades
#
# 3. Bagging, Pasting OOB
#
# Bagging: muestreo aleatorio de datos de entrenamiento que permite el reemplazo de instancias.
#
# Pasting: hace lo mismo pero sin reemplazo
#
# el pasting disminuye la varianza global
#
# el sistema competo se vuelve muy escalable, se pueden desplegar varios algoritmos en paralelo.
#
# instancias fuera de bolsa, 37% aparte
#
# 4. Bosques alestorios
#
# Estrategias de muestreo
#
# Parches aleatorios: muestra instancias y características
#
# subespacios aleatorios: muestra solo las características.
#
# arboles extra: unmbreales de division aleatorios
#
# 5. Algoritmos de Boosting
#
# paso 1. Entrenar un clasificador
#
# paso 2: aumentar peso a instancias con errores
#
# paso 3: entrenar nuevo clasificador
#
# paso 4:repetir el ciclo
#
# la corrección secuencial ajusta los errores progresivamente
#
# variables continuas muy dispersas y agruparlas en contenedores
#
# 6. Stacking
#
# entrenar un nuevo algoritmo supremo (mezclador), les aplica su inteligencia matematica para mejorar las predicciones de los algoritmos bajo el
#
# ¿que desafios globales resolverán estos algoritmos?
#
# -------------------------------------------------------------------------
#
# en google ai studio, construir una aplicacion para android realiza una aplicacion apra entender el concepto de gradient boosting de forma pedagógica, lúdica, explicativa, visual con ejemplos visuales e interactivos, mediante gráficos dinámicos en 2D y 3D, que expliquen la pérdida en cada iteración paso a paso, del algoritmo de machine learning se lo mas detallado posible, y holístico; explicame todo lo relacionado e incluye un dashboard que muestre el ajuste progresivo de los residuos en tiempo real; que me permita entender el manejo de los hiperparametros y como afectan la convergencia mediante controles deslizanes interactivos y comparativos de modelos usando el dataset iris
